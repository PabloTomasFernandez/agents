# %% [markdown]
# ## Bienvenidos al Segundo Laboratorio - Semana 1, Día 3
#
# ¡Hoy trabajaremos con muchos modelos! Así nos familiarizaremos con las API.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../../assets/stop.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">Punto importante: por favor, léelo</h2>
# <span style="color:#ff7800;">La forma en que colaboro contigo puede ser diferente a la de otros cursos que hayas hecho. Prefiero no escribir código mientras tu miras. En su lugar, ejecuto Jupyter Labs, como este, y te doy una idea de lo que está sucediendo. Te sugiero que lo hagas lo mismo con cuidado, después de ver la clase. Agrega declaraciones de impresión para comprender qué sucede y luego crea tus propias variaciones.<br/><br/>Si tienes tiempo, me encantaría que enviaras una pull request en la carpeta community_contributions; las instrucciones se encuentran en los recursos. Además, si tienes una cuenta de Github, úsala para mostrar tus variaciones. Esta práctica no solo es esencial, sino que también demuestra tus habilidades a otros, incluyendo quizás futuros clientes o empleadores...
# </span>
# </td>
# </tr>
# </table>

# %%
# Comenzamos con las importaciones: pídale a ChatGPT que le explique cualquier paquete que no conozca# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display
import re

# %%
# ¡Recuerda siempre incluir esto siempre!
load_dotenv(override=True)
# Out:
# True

# %%
# Imprime los prefijos de clave para ayudar con cualquier depuración

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
ollama_api_key = os.getenv('API_KEY_OLLAMA')

if openai_api_key:
    print(f"La clave API de OpenAI existe y empieza por {openai_api_key[:8]}")
else:
    print("La clave API de OpenAI no existe.")
    
if anthropic_api_key:
    print(f"La clave API de Anthropic existe y empieza por {anthropic_api_key[:7]}")
else:
    print("La clave API de Anthropic no existe.")

if google_api_key:
    print(f"La clave API de Google existe y empieza por {google_api_key[:2]}")
else:
    print("La clave API de Google no existe.")

if deepseek_api_key:
    print(f"La clave API de DeepSeek existe y empieza por {deepseek_api_key[:3]}")
else:
    print("La clave API de DeepSeek no existe.")

if groq_api_key:
    print(f"La clave API de Groq existe y empieza por {groq_api_key[:4]}")
else:
    print("La clave API de Groq no existe.")

if ollama_api_key:
    print(f"La clave API de Ollama existe y empieza por {ollama_api_key[:4]}")
else:
    print("La clave API de Ollama no existe.")
# Out:
# La clave API de OpenAI no existe.
# La clave API de Anthropic no existe.
# La clave API de Google no existe.
# La clave API de DeepSeek no existe.
# La clave API de Groq existe y empieza por gsk_
# La clave API de Ollama existe y empieza por olla
# La clave API de Groq existe y empieza por gsk_

# %%
request = "Por favor, propon una pregunta compleja y con matices que pueda plantear a varios LLM para evaluar su inteligencia."
request += "Responde solo con la pregunta, sin explicaciones."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Por favor, propon una pregunta compleja y con matices que pueda plantear a varios LLM para evaluar su inteligencia.Responde solo con la pregunta, sin explicaciones.'}]

# %% [markdown]
# ## Para la siguiente celda, utilizaremos Ollama
#
# Ollama ejecuta un servicio web local que ofrece un endpoint compatible con OpenAI,
# y ejecuta modelos localmente utilizando código de alto rendimiento en C++.
#
# Si no tienes Ollama, instálalo aquí visitando [https://ollama.com](https://ollama.com), luego presiona Descargar y sigue las instrucciones.
#
# Después de instalarlo, deberías poder visitar: [http://localhost:11434](http://localhost:11434) y ver el mensaje "Ollama está en funcionamiento"
#
# Es posible que necesites reiniciar Cursor (y tal vez reiniciar el sistema). Luego abre un Terminal (control+\`) y ejecuta `ollama serve`
#
# Comandos útiles de Ollama (ejecuta estos en el terminal o con un signo de exclamación en este cuaderno):
#
# - `ollama pull <nombre_del_modelo>` descarga un modelo localmente
# - `ollama ls` lista todos los modelos que has descargado
# - `ollama rm <nombre_del_modelo>` elimina el modelo especificado de tus descargas

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">¡Muy importante - ignóralo bajo tu propio riesgo!</h2>
#             <span style="color:#ff7800;">El modelo llamado <b>llama3.3</b> es DEMASIADO grande para las computadoras domésticas; ¡no está destinado para computación personal y consumirá todos tus recursos! Quédate con el modelo de tamaño adecuado <b>llama3.2</b> o <b>llama3.2:1b</b> y si deseas algo más grande, prueba con llama3.1 o variantes más pequeñas de Qwen, Gemma, Phi o DeepSeek. Consulta <A href="https://ollama.com/models">la página de modelos de Ollama</a> para ver la lista completa de modelos y tamaños.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
modelo = "llama3.2:3b"

# %%
# client = OpenAI(
#     base_url="http://localhost:11434/v1",
#     api_key= ollama_api_key
# )
# response = client.chat.completions.create(
#     model= modelo,
#     messages=messages,
# )
# question = response.choices[0].message.content
# print(question)
# Out:
# "Un grupo de amigos deciden visitar un museo virtual que ofrece una versión virtualizada del laboratorio donde Pablo Picasso creó algunas de sus obras maestras, incluyendo la famosa 'Les Demoiselles d'Avignon'. Durante su visita, uno de los amigos, un fanático de César Chávez, descubre una nueva versión menos conocida de esta obra que se cree que fue creada por el propio Piccaso después del atentado contra él en 1934. ¿Es probable que la versión descubierta sea auténtica o haya sido manipulada por los curadores del museo, y si es auténtica, qué implicaciones tiene esto para nuestra comprensión de la obra?".

# %%
groq = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key= groq_api_key
)

model_name = "qwen/qwen3-32b"

response = groq.chat.completions.create(model=model_name, messages=messages)
question = response.choices[0].message.content
question = re.sub(r'<think>.*?</think>', '', question, flags=re.DOTALL).strip()
print(question)
# Out:
# ¿Cómo evaluarías, desde perspectivas éticas utilitarias, deontológicas y basadas en derechos, un escenario hipotético donde una inteligencia artificial debe decidir si redirigir un tren que, al desviar, evitará que se maten a cinco personas en una vía pero conllevará la muerte de tres en otra, considerando además un factor adicional: todas las vías están conectadas a infinitos otros senderos por un sistema de espejos cuánticos (inspirado en el *paradoja de Ross-Littlewood*), donde cada acción genera efectos colaterales en dimensiones irreductibles, y la decisión no solo requiere cálculo probabilístico, sino también reconciliación lógica entre modelos discretos e infinitos?

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %%
client = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key= ollama_api_key
)

# %%
# Vamos a usar el modelo llama3.2:3b de ollama

model_name = "llama3.2:3b"

response = client.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(modelo)
answers.append(answer)
# Out:
# Este escenario hipotético plantea una serie de desafíos éticos complejos que abarcan diferentes enfoques filosóficos y matemáticos. A continuación, presento una evaluación desde perspectivas éticas utilitarias, deontológicas y basadas en derechos.
#
# **Perspectiva Utilitarista:**
#
# La principal preocupación del utilitarismo es maximizar el bienestar general y minimizar el sufrimiento. En este escenario, la inteligencia artificial (IA) debe decidir entre dos opciones:
# 1) Redirigir el tren para matar a tres personas en una vía conllevante.
# 2 ) No redirigir el tren y permitir que se maten a cinco personas.
#
# Desde esta perspectiva, un utilitarista consideraría la opción de no redirigir el tren como la correcta, ya que se minimiza el número overall de muertes. Esta decisión puede ser justificada por el principio "darse cuenta del mayor bien para el mayor número". Sin embargo, podrías argumentar que esta decisión está basada en una suposición limitante, ya que la opción preferida no considera las implicaciones éticas de generar muertes en dimensiones irreductibles.
#
# **Perspectiva Deontológica:**
#
# La esfera moral se considera fundamental y absoluta desde un punto de vista deontológico. En este escenario, la respuesta correcta vendría dada por una serie de reglas u obligaciones morales como el principio de non maleficence ("no hacer daño") o el imperativo categórico de Immanuel Kant (*Actúa según tu deber*). A partir de estos principios éticos, parece lógico decidir no redirigir el tren en ninguna circunstancia y permitir que todos los trenes sigan sus trayectorias originales. La desaparición de vías y viajeros de otras dimensiones también podría generar preocupación sobre si son moralmente distintas (porque tienen ciertas características en particular) los vivos versus los muertos.
#
# **Perspectiva Basada en Derechos:**
#
# En este escenario, el dilema se convierte en una cuestión de derechos humanos y dignidad. Desde esta perspectiva, la decisión parece más ligada a un caso particular y por derecho propio (en términos de los muertos condenados a la vía alternativa) que a principios éticos generalizables. Si consideramos los derechos de las personas involucradas, la decisión se volvería muy difícil por el número de afectados.
#
# **Perspectiva Cuántico-Estadística:**
#
# El factor adicional del sistema de espejos cuánticos y su relevancia para nuestro escenario hipotético introduce variables no cuantitativas sobre cual las reglas morales tendrán aplicación. Es muy relevante abordar estas dimensiones que no pueden darse apuntalando la teoría científica, ya que no tienen precedentes históricos ni empíricos.
#
# Teniendo en cuenta estos aspectos éticos y matemáticos, es evidente que esta solución hipotética sería compleja para un agente de inteligencia artificial y requeriría algún grado de discusión, deliberación o incluso apelaciones internacionales que puedan resolver el misterio del cuánto ser dignamente conmemorado el número de personas afectadas por la redirección o no del tren.

# %%
# Vamos a usar el modelo mistral:7b de ollama

model_name = "mistral:7b"

response = client.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Vamos a usar el modelo phi3.5 de ollama

model_name = "phi3.5"

response = client.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Las tendencias culturales globales han impactado significativлова el tejido social, particularmente para miembros de minorías étnicas dentro de sociedades diversas. Estos efectos pueden ser tanto positivos como negativos y puede resultar en una compleja interacción entre identidad cultural y propósito nacional o comunitario compartido que subyace a los conceptos contemporáneos de pertenencia e identidad.
#
# Un ejemplo reciente es la proliferación del "cosmopolitismo" donde las ideas culturales se mezclan fácilmente debido al énfasis en prácticas globales y marcas comerciales; esta globalización a veces perjudica los sentimientos de identidad, ya que puede hacer sutil e irreversible el declive tradicional. Por ejemplo, minoridades como afroamericanos se pueden experimentar una tensión entre la creciente influencia asiática en ciertas industrias culturalmente dominantes (cine/télviso), dejando a miembros de estas comunidades reevaluando su papel únicamente dentro del grupo racial tradicional y también unirse al amplio continuum global, incluso pendientes potenciales deslegitimaciones o menosprecios.
#
# Además la cultura pop frecuentemente promueve estereotipos de minorías étnicas en una manera casual - considera trabajadores asiáticos como extraños precisamente conductores inteligentes, que pueden contribuir a percibir estas culturas no solo fuera del alcance local sino también dentro. Esto puede ser problemático ya que fomentará un estigma basado único y exotismo cultural en lugar de entender la complejidad holística e individualidades propias presente entre todos los miembros de estos grupos étnicos particulares, negando sus propio historias únicas y contextos.
#
# Sin embargo, es importante reconocer las posibles simplificaciones que esto representa una visión limitada porque ofrece un panorama demasiado crudo - muchos individuos en cualquier minoría encuentran suerte mezclando sus costumbres propias con elementos presentes dentro de la cultura general —un fenómeno cultural reciente conocido como 'amalgamación', tal vez visible a través del baile hip hop fusionada comúnmente practicado por miembros afrocaucásicos, donde danza (arte) se percibe uniendo tradiciones culturales.
#
# En otro marco potencial de construcción crítica es destacar los intentos que llevan hacia el multilingue y múltiple culturalidad – la creciente popularización del bilingüismo, particularmente entre las generaciones más jóvenes dentro muchas minorías étnicas podría resultarte en una potencial soberbia nacional pero también un reconocimiento de identidad cruzada. Examinando el movimiento hip hop: comienza como expresión artística originaria afrodescendiente, ahora se fusiona cada vez más con elementos latinos y otros – reflejando estas interacciones dinámicas entre culturas; sin embargo al mismo tiempo las identidades específicas del origen dentro el movimiento pueden comenzar perdidas o marginadas.
#
# En conclusión: los efectos sociales de la cultura globalizadora puede ser bastante cambiantes para minorías – ya sea deslegitimando sus contribuciones únicas al tejido sociocultural en una tierra extranjera, ofreciendo nuevas formas que pueden fusionar tradiciones culturales (como dentro hip hop), la creciente multilingüismo y cultura biculturalidad. Es imperativo desestimar estereotipos simplistas mientras reconocen las complejidades inherentes e historias únicas presentes en individuos de cualquier minoría étnica, así se pueda contribuir una manera más humilde a la diversidad inclusiva alentando conversaciones dinámicas que mejoran el entendimiento y respeto.
#
# Nota: Esta respuesta está elaborada para dar un marco sólido pero conciso de consideración social en torno a los impactos culturales globales sobre minorías étnicas dentro sociedades diversas, utilizando ejemplos específicos recientes y ofreciendo críticas constructivas al poten回 la propaginación simplificaciones o estereotipos presentes. Sin embargo para una exploración más profunda considerar historias personales bajo estas perspectivas podría proporcionar valiosa compr

# %%
groq = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key= groq_api_key
)

model_name = "qwen/qwen3-32b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content
answer = re.sub(r'<think>.*?</think>', '', answer, flags=re.DOTALL).strip()

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# <think>
# Okay, so the user is asking about the authenticity of a newly discovered version of Picasso's "Les Demoiselles d'Avignon" mentioned in a virtual museum. The scenario includes a friend who's a Cesar Chavez fan finding it after an alleged 1934 attack on Picasso. First, I need to verify if Picasso was actually attacked in 1934. Let me recall. Picasso was involved in the Spanish Civil War, but I don't remember a specific attack on him in 1934. Maybe they mixed up dates with other events.
#
# Next, I should consider the timeline of "Les Demoiselles d'Avignon." It was created in 1907. Picasso might have altered it later, but any versions after that would be rare. He did work on it in 1907 and maybe made changes in 1916, but after that, he wasn't altering it much. The 1934 attack—if that's real—would have been after he moved to France. But I don't recall any credible historical records of such an event.
#
# Now, the user is asking if the version found in the virtual museum is authentic or a curators' manipulation. Since virtual museums can have digital recreations, perhaps the "discovered" work might be a digital reproduction or a hypothetical version rather than an original. But if it claims to be a real version Picasso created after 1934, that's questionable because he died in 1973. Wait, no, Picasso was alive in 1934, but if he created a new version after an attack, that's a new piece of info. However, the original Les Demoiselles was completed in 1907. Picasso did create variations, but most were done around the time of the original.
#
# Another angle: Cesar Chavez fan discovering it. Maybe a red herring unless there's a connection between their activism and Picasso's work? Probably not. The friend's interest in Cesar Chavez might just be part of the story setup.
#
# Implications if it's real: It would add to the provenance and understanding of Picasso's creative process. But if it's a fake, the museum might be trying to generate attention or have ulterior motives. Also, considering the virtual aspect, it's possible the work is a digital reconstruction, not an original. The question is whether the museum is authenticating the work properly.
#
# Need to check if there are any known records of a later version. The only versions I know are the original and some preparatory works like the "Study for Les Demoiselles d'Avignon" in 1907. After 1907, he didn't revisit the subject much. A version created after a supposed attack in 1934 would be unprecedented. Also, Picasso's work in the 1930s was influenced by the Spanish Civil War, leading to "Guernica" in 1937, but that's a different theme.
#
# In conclusion, the likelihood of the work being authentic is low because there's no historical evidence of an attack in 1934 or a later version of the painting. The museum might be presenting a manipulated or fabricated piece. If authentic, it would change art history by showing Picasso's engagement with the Les Demoiselles theme much later than documented. But given the lack of evidence, the more probable answer is that it's a manipulation by the curators to engage viewers or for educational purposes.
# </think>
#
# La probabilidad de que la versión descubierta en el museo virtual sea auténtica es extremadamente baja o nula, y las implicaciones dependerían de la naturaleza de la manipulación o creación del curador. Aquí está el análisis detallado:
#
# ---
#
# ### **1. Verificación histórica: ¿Picasso creó una versión posterior de "Les Demoiselles d'Avignon" tras un atentado en 1934?**
# - **No hay registro histórico de un atentado contra Picasso en 1934.**
#   Pablo Picasso vivió de 1881 a 1973, y aunque estuvo activo durante la Guerra Civil Española (1936-1939), no hay evidencia verificada de un ataque en 1934. Su obra "Guernica" (1937) está relacionada con los conflictos de ese período, pero no se menciona ninguna conexión con una supuesta "Les Demoiselles" post-ataque.
#   - *Les Demoiselles d'Avignon* (1907) fue pintada al inicio del Cubismo, y Picasso no volvió a abordar el tema de manera significativa. Las únicas versiones conocidas son las preparatorias de 1907 y una copia parcial hecha en 1916, que no se relaciona con un "ataque".
#
# ---
#
# ### **2. ¿Podría ser auténtica la versión descubierta?**
# - **No hay evidencia documental.** Picasso no creó una versión radicalmente diferente de *Les Demoiselles* en 1934 o después. Las obras posteriores al 1910 que tratan temas similares son reinterpretaciones de su estilo cubista o su fase de los años 1930 (como "Las Meninas", 1957, basada en Velázquez).
# - **La tecnología virtual como clave.** El escenario menciona un "museo virtual", lo que sugiere que se trata de una **recreación digital** o una **hipótesis especulativa** generada por los curadores para destacar una interpretación alternativa. En el mundo del arte, los museos a veces presentan versiones "falsas" o hipotéticas para explorar qué podría haber pasado si el artista hubiera seguido otro camino.
#   - Si la "versión descubierta" es una **obra real** (física o digital) alegada como auténtica, sería un hallazgo monumental, pero **carece de apoyo histórico, técnica o documental**.
#
# ---
#
# ### **3. Implicancias si fuera auténtica (hipótesis teórica)**
# Si (contrariando las pruebas actuales) se confirmara una versión posterior de *Les Demoiselles* obra de Picasso tras un "ataque", las implicaciones serían significativas:
# - **Cambiaría la narrativa del Cubismo.** Se necesitaría reexaminar la evolución de su estilo, explorando qué factores (un ataque, cambios personales o sociales) lo llevaron a reinterpretar esta obra icónica.
# - **Validez artística y técnica.** Se estudiaría su autoría mediante análisis de la paleta, firma, técnica y estilos contemporáneos.
# - **Contexto histórico.** Un ataque en 1934 (aunque ficticio) podría vincularse con el contexto de la Guerra Civil o la creación de "Guernica", pero esto exige pruebas documentales.
#
# ---
#
# ### **4. Posibilidad de manipulación por los curadores**
# Es probable que los curadores hayan diseñado esta "nueva versión" para:
# - **Atracción mediática o educativa.** Generar interés al plantear una historia alternativa sobre Picasso, combinando arte, historia y un toque de misterio (el "fanático de César Chávez" tal vez para resaltar conexiones sociales).
# - **Explorar teorías alternativas.** Los museos digitales a menudo proponen escenarios hipotéticos (ejemplo: "¿Qué hubiera pasado si Van Gogh hubiera vivido más años?") para fomentar la creatividad crítica.
# - **Errores históricos.** Los datos sobre un "ataque" de 1934 o una obra posterior son invención, pero bien podrían ser usados para ilustrar la fragilidad de la autenticidad en el arte.
#
# ---
#
# ### **Conclusión**
# La versión descubierta **no es auténtica**; es más probable una obra **hipotética, digital o manipulada** por los curadores del museo virtual. Su propósito sería artístico, pedagógico o especulativo, no histórico. Si en la ficción se confirmara su autenticidad, transformaría drásticamente nuestra comprensión del trabajo de Picasso, pero en la realidad, las pruebas actuales no respaldan tal escenario.
#
# **Nota adicional:** La conexión con César Chávez parece ser un elemento narrativo para personalizar la historia, no una relación sustancial con *Les Demoiselles d'Avignon*.

# %%
# ¿Donde estamos?

print(competitors)
print(answers)
# Out:
# ['llama3.2:3b', 'mistral:7b', 'phi3.5']
# ['El impacto social de las tendencias culturales globales en la identidad y la pertenencia de un miembro de una minoría étnica en una sociedad diversa es un tema complejo y multifacético que requiere una comprensión profunda de los cuestiones éticas, sociales y políticas involucradas.\n\n**Los efectos positivos:**\n\nLas tendencias culturales globales pueden tener un impacto positivo en la identidad y la pertenencia de los miembros de las minorías étnicas en varias maneras:\n\n1. **Representación y reconocimiento:** Las tendencias culturales globales pueden contribuir a la representación y el reconocimiento de las experiencias y perspectivas de las minorías étnicas en los medios, instituciones educativas y espacios públicos. Esto proporciona una imagen más precisa y diversificada del mundo global.\n2. **Influencia cultural:** Los miembros de las minorías étnicas pueden sentirse identificados y conectados con la cultura global que se refleja en su propia herencia, lo que puede mejorar su sentido de pertenencia a la comunidad global.\n3. **Oportunidades laborales y educativas:** Las tendencias culturales globales pueden proporcionar oportunidades laborales, educativas y de networking que se centran en la diversidad cultural, lo que puede ser beneficioso para los miembros de las minorías étnicas.\n\n**Los efectos negativos:**\n\nSin embargo, también existen posibles efectos negativos de las tendencias culturales globales en la identidad y la pertenencia de los miembros de las minorías étnicas:\n\n1. **Simplificaciones y estereotipos:** Las discusiones dominantes sobre las tendencias culturales globales pueden simplificar o reducir a las experiencias y perspectivas complejas de las minorías étnicas, perpetuando los estereotipos y prejuicios.\n2. **Culturización:** La adopción de la cultura global puede llevar a la culturaización, es decir, la pérdida de características culturales únicas que definen a una comunidad específica. Esto puede afectar negativamente su identidad y pertenencia.\n3. **Exclusión y marginación:** La influencia dominanté de las tendencias culturales globales puede conducir a la exclusión y la marginación de ciertos grupos culturales, perpetuando desigualdades y injusticias socias.\n\n**Ejemplos históricos:**\n\nA continuación, se presentan algunos ejemplos históricos que ilustran el impacto social de las tendencias culturales globales en la identidad y la pertenencia de los miembros de las minorías étnicas:\n\n1. **La inmigración a los Estados Unidos:** La inmigración a los EE.UU. durante la década de 1980, predominantemente de origen latinoamericano, contribuyó al crecimiento cultural de la música latina y el aumento de una identidad globalizada latin@.\n2. **La creciente influencia del Bollywood en el mundo occidental:** La popularización del cine bollywoodi en países como Reino Unido e India ha permitido que los miembros de las minorías étnicas se sientan más conectados con sus raíces culturales.\n\n**Críticas constructivas:**\n\nPara abordar efectivamente el impacto social de las tendencias culturales globales, es necesario:\n\n1. **Desafiar simplificaciones y estereotipos:** Abordar las simplificaciones y los estereotipos utilizados en las discusiones dominantes sobre las tendencias culturales globales.\n2. **Fomentar la inclusión cultural:** Incentivar a las comunidades culturales complejas hacia un diálogo inclusivo, donde todas las experiencias de diversidad son valoradas y representadas.\n3. **Promover una comprensión ética del mundo global:** Educación crítica es fundamental para comprender los efectos culturales globales en la identidad y la inclusión de individuos minoritarios con perspectiva inter disciplinaria, contextual y éticamente comprometidos.\n\nAl considerar estos ejemplos e implícitos históricos, como well as constructivos críticas hacia simplificaciones y estereotipos utilizados en discusiones dominantes sobre las tendencias globales cultura, podemos trabajar más efectivamente para abor ...

# %%
# Es bueno saber cómo se utiliza "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competidor: {competitor}\n\n{answer}")
# Out:
# Competidor: llama3.2:3b
#
# El impacto social de las tendencias culturales globales en la identidad y la pertenencia de un miembro de una minoría étnica en una sociedad diversa es un tema complejo y multifacético que requiere una comprensión profunda de los cuestiones éticas, sociales y políticas involucradas.
#
# **Los efectos positivos:**
#
# Las tendencias culturales globales pueden tener un impacto positivo en la identidad y la pertenencia de los miembros de las minorías étnicas en varias maneras:
#
# 1. **Representación y reconocimiento:** Las tendencias culturales globales pueden contribuir a la representación y el reconocimiento de las experiencias y perspectivas de las minorías étnicas en los medios, instituciones educativas y espacios públicos. Esto proporciona una imagen más precisa y diversificada del mundo global.
# 2. **Influencia cultural:** Los miembros de las minorías étnicas pueden sentirse identificados y conectados con la cultura global que se refleja en su propia herencia, lo que puede mejorar su sentido de pertenencia a la comunidad global.
# 3. **Oportunidades laborales y educativas:** Las tendencias culturales globales pueden proporcionar oportunidades laborales, educativas y de networking que se centran en la diversidad cultural, lo que puede ser beneficioso para los miembros de las minorías étnicas.
#
# **Los efectos negativos:**
#
# Sin embargo, también existen posibles efectos negativos de las tendencias culturales globales en la identidad y la pertenencia de los miembros de las minorías étnicas:
#
# 1. **Simplificaciones y estereotipos:** Las discusiones dominantes sobre las tendencias culturales globales pueden simplificar o reducir a las experiencias y perspectivas complejas de las minorías étnicas, perpetuando los estereotipos y prejuicios.
# 2. **Culturización:** La adopción de la cultura global puede llevar a la culturaización, es decir, la pérdida de características culturales únicas que definen a una comunidad específica. Esto puede afectar negativamente su identidad y pertenencia.
# 3. **Exclusión y marginación:** La influencia dominanté de las tendencias culturales globales puede conducir a la exclusión y la marginación de ciertos grupos culturales, perpetuando desigualdades y injusticias socias.
#
# **Ejemplos históricos:**
#
# A continuación, se presentan algunos ejemplos históricos que ilustran el impacto social de las tendencias culturales globales en la identidad y la pertenencia de los miembros de las minorías étnicas:
#
# 1. **La inmigración a los Estados Unidos:** La inmigración a los EE.UU. durante la década de 1980, predominantemente de origen latinoamericano, contribuyó al crecimiento cultural de la música latina y el aumento de una identidad globalizada latin@.
# 2. **La creciente influencia del Bollywood en el mundo occidental:** La popularización del cine bollywoodi en países como Reino Unido e India ha permitido que los miembros de las minorías étnicas se sientan más conectados con sus raíces culturales.
#
# **Críticas constructivas:**
#
# Para abordar efectivamente el impacto social de las tendencias culturales globales, es necesario:
#
# 1. **Desafiar simplificaciones y estereotipos:** Abordar las simplificaciones y los estereotipos utilizados en las discusiones dominantes sobre las tendencias culturales globales.
# 2. **Fomentar la inclusión cultural:** Incentivar a las comunidades culturales complejas hacia un diálogo inclusivo, donde todas las experiencias de diversidad son valoradas y representadas.
# 3. **Promover una comprensión ética del mundo global:** Educación crítica es fundamental para comprender los efectos culturales globales en la identidad y la inclusión de individuos minoritarios con perspectiva inter disciplinaria, contextual y éticamente comprometidos.
#
# Al considerar estos ejemplos e implícitos históricos, como well as constructivos críticas hacia simplificaciones y estereotipos utilizados en discusiones dominantes sobre las tendencias globales cultura, podemos trabajar más efectivamente para abordar la complequidad de los impactos sociales que tienen estas tendencias culturales globales en el mundo diverso.
# Competidor: mistral:7b
#
#  La interacción entre las tendencias culturales globales y la identidad y pertenencia de miembros de minorías étnicas en una sociedad diversa puede ser complicada y multifacética. Estas interacciones pueden abarcar efectos positivos, negativos, o complejos dependiendo de la cultura dominante, el contexto histórico y social, y los esfuerzos de inclusión o exclusión en la sociedad.
#
# Uno de los ejemplos más prominentes es la difusión global del hip-hop en la década de 1980 y sus efectos sobre las personas de color en América del Norte, especialmente los afroamericanos y chicanos. El hip-hop actuó como una herramienta para preservar y promover su cultura local, en el contexto de la disminución de la influencia de movimientos culturales colectivos previos y el surgimiento de nuevos desafíos socioeconómicos. Sin embargo, también se utilizó la comercialización del hip-hop por la cultura dominante para sencillez, estereotipo y objetivación de las personas de color, especialmente en los medios.
#
# Por otro lado, la globalización ha proporcionado nuevas oportunidades para promover la diversidad cultural a través de plataformas de comunicación mundial como Internet. Estas plataformas han ayudado a las minorías étnicas a compartir su cultura y tradiciones entre sí y con los no-dominantes, lo que ha contribuido a la construcción de sus identidades más fuertes e informadas. Sin embargo, también pueden presentar desafíos cuando se combina con el nacionalismo o las discusiones políticas que pueden hacer uso del racismo, xenofobia y otras ideologías discriminatorias para propagar estereotipos degradantes sobre personas pertenecientes a comunidades a otras partes de la sociedad.
#
# En conclusion, las tendencias culturales globales tienen un impacto complejo en el contexto social e identidad de miembros de minorías étnicas. Es necesario abordar con precaución los estereotipos y simplicaciones utilizados en discursos dominantes, al tiempo que se reconoce la importancia de las oportunidades que ofrecen estas tendencias para fortalecer e informar la identidad de las minorías étnicas y promover la diversidad cultural.
# Competidor: phi3.5
#
# Las tendencias culturales globales han impactado significativлова el tejido social, particularmente para miembros de minorías étnicas dentro de sociedades diversas. Estos efectos pueden ser tanto positivos como negativos y puede resultar en una compleja interacción entre identidad cultural y propósito nacional o comunitario compartido que subyace a los conceptos contemporáneos de pertenencia e identidad.
#
# Un ejemplo reciente es la proliferación del "cosmopolitismo" donde las ideas culturales se mezclan fácilmente debido al énfasis en prácticas globales y marcas comerciales; esta globalización a veces perjudica los sentimientos de identidad, ya que puede hacer sutil e irreversible el declive tradicional. Por ejemplo, minoridades como afroamericanos se pueden experimentar una tensión entre la creciente influencia asiática en ciertas industrias culturalmente dominantes (cine/télviso), dejando a miembros de estas comunidades reevaluando su papel únicamente dentro del grupo racial tradicional y también unirse al amplio continuum global, incluso pendientes potenciales deslegitimaciones o menosprecios.
#
# Además la cultura pop frecuentemente promueve estereotipos de minorías étnicas en una manera casual - considera trabajadores asiáticos como extraños precisamente conductores inteligentes, que pueden contribuir a percibir estas culturas no solo fuera del alcance local sino también dentro. Esto puede ser problemático ya que fomentará un estigma basado único y exotismo cultural en lugar de entender la complejidad holística e individualidades propias presente entre todos los miembros de estos grupos étnicos particulares, negando sus propio historias únicas y contextos.
#
# Sin embargo, es importante reconocer las posibles simplificaciones que esto representa una visión limitada porque ofrece un panorama demasiado crudo - muchos individuos en cualquier minoría encuentran suerte mezclando sus costumbres propias con elementos presentes dentro de la cultura general —un fenómeno cultural reciente conocido como 'amalgamación', tal vez visible a través del baile hip hop fusionada comúnmente practicado por miembros afrocaucásicos, donde danza (arte) se percibe uniendo tradiciones culturales.
#
# En otro marco potencial de construcción crítica es destacar los intentos que llevan hacia el multilingue y múltiple culturalidad – la creciente popularización del bilingüismo, particularmente entre las generaciones más jóvenes dentro muchas minorías étnicas podría resultarte en una potencial soberbia nacional pero también un reconocimiento de identidad cruzada. Examinando el movimiento hip hop: comienza como expresión artística originaria afrodescendiente, ahora se fusiona cada vez más con elementos latinos y otros – reflejando estas interacciones dinámicas entre culturas; sin embargo al mismo tiempo las identidades específicas del origen dentro el movimiento pueden comenzar perdidas o marginadas.
#
# En conclusión: los efectos sociales de la cultura globalizadora puede ser bastante cambiantes para minorías – ya sea deslegitimando sus contribuciones únicas al tejido sociocultural en una tierra extranjera, ofreciendo nuevas formas que pueden fusionar tradiciones culturales (como dentro hip hop), la creciente multilingüismo y cultura biculturalidad. Es imperativo desestimar estereotipos simplistas mientras reconocen las complejidades inherentes e historias únicas presentes en individuos de cualquier minoría étnica, así se pueda contribuir una manera más humilde a la diversidad inclusiva alentando conversaciones dinámicas que mejoran el entendimiento y respeto.
#
# Nota: Esta respuesta está elaborada para dar un marco sólido pero conciso de consideración social en torno a los impactos culturales globales sobre minorías étnicas dentro sociedades diversas, utilizando ejemplos específicos recientes y ofreciendo críticas constructivas al poten回 la propaginación simplificaciones o estereotipos presentes. Sin embargo para una exploración más profunda considerar historias personales bajo estas perspectivas podría proporcionar valiosa compr

# %%
# Vamos a juntarlo todo - nota cómo usamos en este caso "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"#Respuesta del competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# #Respuesta del competitor 1
#
# El impacto social de las tendencias culturales globales en la identidad y la pertenencia de un miembro de una minoría étnica en una sociedad diversa es un tema complejo y multifacético que requiere una comprensión profunda de los cuestiones éticas, sociales y políticas involucradas.
#
# **Los efectos positivos:**
#
# Las tendencias culturales globales pueden tener un impacto positivo en la identidad y la pertenencia de los miembros de las minorías étnicas en varias maneras:
#
# 1. **Representación y reconocimiento:** Las tendencias culturales globales pueden contribuir a la representación y el reconocimiento de las experiencias y perspectivas de las minorías étnicas en los medios, instituciones educativas y espacios públicos. Esto proporciona una imagen más precisa y diversificada del mundo global.
# 2. **Influencia cultural:** Los miembros de las minorías étnicas pueden sentirse identificados y conectados con la cultura global que se refleja en su propia herencia, lo que puede mejorar su sentido de pertenencia a la comunidad global.
# 3. **Oportunidades laborales y educativas:** Las tendencias culturales globales pueden proporcionar oportunidades laborales, educativas y de networking que se centran en la diversidad cultural, lo que puede ser beneficioso para los miembros de las minorías étnicas.
#
# **Los efectos negativos:**
#
# Sin embargo, también existen posibles efectos negativos de las tendencias culturales globales en la identidad y la pertenencia de los miembros de las minorías étnicas:
#
# 1. **Simplificaciones y estereotipos:** Las discusiones dominantes sobre las tendencias culturales globales pueden simplificar o reducir a las experiencias y perspectivas complejas de las minorías étnicas, perpetuando los estereotipos y prejuicios.
# 2. **Culturización:** La adopción de la cultura global puede llevar a la culturaización, es decir, la pérdida de características culturales únicas que definen a una comunidad específica. Esto puede afectar negativamente su identidad y pertenencia.
# 3. **Exclusión y marginación:** La influencia dominanté de las tendencias culturales globales puede conducir a la exclusión y la marginación de ciertos grupos culturales, perpetuando desigualdades y injusticias socias.
#
# **Ejemplos históricos:**
#
# A continuación, se presentan algunos ejemplos históricos que ilustran el impacto social de las tendencias culturales globales en la identidad y la pertenencia de los miembros de las minorías étnicas:
#
# 1. **La inmigración a los Estados Unidos:** La inmigración a los EE.UU. durante la década de 1980, predominantemente de origen latinoamericano, contribuyó al crecimiento cultural de la música latina y el aumento de una identidad globalizada latin@.
# 2. **La creciente influencia del Bollywood en el mundo occidental:** La popularización del cine bollywoodi en países como Reino Unido e India ha permitido que los miembros de las minorías étnicas se sientan más conectados con sus raíces culturales.
#
# **Críticas constructivas:**
#
# Para abordar efectivamente el impacto social de las tendencias culturales globales, es necesario:
#
# 1. **Desafiar simplificaciones y estereotipos:** Abordar las simplificaciones y los estereotipos utilizados en las discusiones dominantes sobre las tendencias culturales globales.
# 2. **Fomentar la inclusión cultural:** Incentivar a las comunidades culturales complejas hacia un diálogo inclusivo, donde todas las experiencias de diversidad son valoradas y representadas.
# 3. **Promover una comprensión ética del mundo global:** Educación crítica es fundamental para comprender los efectos culturales globales en la identidad y la inclusión de individuos minoritarios con perspectiva inter disciplinaria, contextual y éticamente comprometidos.
#
# Al considerar estos ejemplos e implícitos históricos, como well as constructivos críticas hacia simplificaciones y estereotipos utilizados en discusiones dominantes sobre las tendencias globales cultura, podemos trabajar más efectivamente para abordar la complequidad de los impactos sociales que tienen estas tendencias culturales globales en el mundo diverso.
#
# #Respuesta del competitor 2
#
#  La interacción entre las tendencias culturales globales y la identidad y pertenencia de miembros de minorías étnicas en una sociedad diversa puede ser complicada y multifacética. Estas interacciones pueden abarcar efectos positivos, negativos, o complejos dependiendo de la cultura dominante, el contexto histórico y social, y los esfuerzos de inclusión o exclusión en la sociedad.
#
# Uno de los ejemplos más prominentes es la difusión global del hip-hop en la década de 1980 y sus efectos sobre las personas de color en América del Norte, especialmente los afroamericanos y chicanos. El hip-hop actuó como una herramienta para preservar y promover su cultura local, en el contexto de la disminución de la influencia de movimientos culturales colectivos previos y el surgimiento de nuevos desafíos socioeconómicos. Sin embargo, también se utilizó la comercialización del hip-hop por la cultura dominante para sencillez, estereotipo y objetivación de las personas de color, especialmente en los medios.
#
# Por otro lado, la globalización ha proporcionado nuevas oportunidades para promover la diversidad cultural a través de plataformas de comunicación mundial como Internet. Estas plataformas han ayudado a las minorías étnicas a compartir su cultura y tradiciones entre sí y con los no-dominantes, lo que ha contribuido a la construcción de sus identidades más fuertes e informadas. Sin embargo, también pueden presentar desafíos cuando se combina con el nacionalismo o las discusiones políticas que pueden hacer uso del racismo, xenofobia y otras ideologías discriminatorias para propagar estereotipos degradantes sobre personas pertenecientes a comunidades a otras partes de la sociedad.
#
# En conclusion, las tendencias culturales globales tienen un impacto complejo en el contexto social e identidad de miembros de minorías étnicas. Es necesario abordar con precaución los estereotipos y simplicaciones utilizados en discursos dominantes, al tiempo que se reconoce la importancia de las oportunidades que ofrecen estas tendencias para fortalecer e informar la identidad de las minorías étnicas y promover la diversidad cultural.
#
# #Respuesta del competitor 3
#
# Las tendencias culturales globales han impactado significativлова el tejido social, particularmente para miembros de minorías étnicas dentro de sociedades diversas. Estos efectos pueden ser tanto positivos como negativos y puede resultar en una compleja interacción entre identidad cultural y propósito nacional o comunitario compartido que subyace a los conceptos contemporáneos de pertenencia e identidad.
#
# Un ejemplo reciente es la proliferación del "cosmopolitismo" donde las ideas culturales se mezclan fácilmente debido al énfasis en prácticas globales y marcas comerciales; esta globalización a veces perjudica los sentimientos de identidad, ya que puede hacer sutil e irreversible el declive tradicional. Por ejemplo, minoridades como afroamericanos se pueden experimentar una tensión entre la creciente influencia asiática en ciertas industrias culturalmente dominantes (cine/télviso), dejando a miembros de estas comunidades reevaluando su papel únicamente dentro del grupo racial tradicional y también unirse al amplio continuum global, incluso pendientes potenciales deslegitimaciones o menosprecios.
#
# Además la cultura pop frecuentemente promueve estereotipos de minorías étnicas en una manera casual - considera trabajadores asiáticos como extraños precisamente conductores inteligentes, que pueden contribuir a percibir estas culturas no solo fuera del alcance local sino también dentro. Esto puede ser problemático ya que fomentará un estigma basado único y exotismo cultural en lugar de entender la complejidad holística e individualidades propias presente entre todos los miembros de estos grupos étnicos particulares, negando sus propio historias únicas y contextos.
#
# Sin embargo, es importante reconocer las posibles simplificaciones que esto representa una visión limitada porque ofrece un panorama demasiado crudo - muchos individuos en cualquier minoría encuentran suerte mezclando sus costumbres propias con elementos presentes dentro de la cultura general —un fenómeno cultural reciente conocido como 'amalgamación', tal vez visible a través del baile hip hop fusionada comúnmente practicado por miembros afrocaucásicos, donde danza (arte) se percibe uniendo tradiciones culturales.
#
# En otro marco potencial de construcción crítica es destacar los intentos que llevan hacia el multilingue y múltiple culturalidad – la creciente popularización del bilingüismo, particularmente entre las generaciones más jóvenes dentro muchas minorías étnicas podría resultarte en una potencial soberbia nacional pero también un reconocimiento de identidad cruzada. Examinando el movimiento hip hop: comienza como expresión artística originaria afrodescendiente, ahora se fusiona cada vez más con elementos latinos y otros – reflejando estas interacciones dinámicas entre culturas; sin embargo al mismo tiempo las identidades específicas del origen dentro el movimiento pueden comenzar perdidas o marginadas.
#
# En conclusión: los efectos sociales de la cultura globalizadora puede ser bastante cambiantes para minorías – ya sea deslegitimando sus contribuciones únicas al tejido sociocultural en una tierra extranjera, ofreciendo nuevas formas que pueden fusionar tradiciones culturales (como dentro hip hop), la creciente multilingüismo y cultura biculturalidad. Es imperativo desestimar estereotipos simplistas mientras reconocen las complejidades inherentes e historias únicas presentes en individuos de cualquier minoría étnica, así se pueda contribuir una manera más humilde a la diversidad inclusiva alentando conversaciones dinámicas que mejoran el entendimiento y respeto.
#
# Nota: Esta respuesta está elaborada para dar un marco sólido pero conciso de consideración social en torno a los impactos culturales globales sobre minorías étnicas dentro sociedades diversas, utilizando ejemplos específicos recientes y ofreciendo críticas constructivas al poten回 la propaginación simplificaciones o estereotipos presentes. Sin embargo para una exploración más profunda considerar historias personales bajo estas perspectivas podría proporcionar valiosa compr

# %%
judge = f"""Estás juzgando una competición entre {len(competitors)} competidores.
A cada modelo se le ha dado esta pregunta:

{question}

Tu trabajo es evaluar cada respuesta por claridad y fortaleza del argumento, y clasificarlas en orden de mejor a peor.
Responde con JSON, y solo JSON, con el siguiente formato:
{{"resultados": ["número del mejor competidor", "número del segundo mejor", "número del tercer mejor", ...]}}

Aquí están las respuestas de cada competidor:

{together}

Ahora responde con el JSON con el orden clasificado de los competidores, nada más. No incluyas formato markdown ni bloques de código."""

# %%
print(judge)
# Out:
# Estás juzgando una competición entre 3 competidores.
# A cada modelo se le ha dado esta pregunta:
#
# "Describe el impacto social de las tendencias culturales globales en la identidad y la pertenencia de un miembro de una minoría étnica en una sociedad diversa, utilizando ejemplos específicos de historia reciente y ofreciendo críticas constructivas a las posibles simplificaciones o estereotipos utilizados en los discursos dominantes."
#
# Tu trabajo es evaluar cada respuesta por claridad y fortaleza del argumento, y clasificarlas en orden de mejor a peor.
# Responde con JSON, y solo JSON, con el siguiente formato:
# {"resultados": ["número del mejor competidor", "número del segundo mejor", "número del tercer mejor", ...]}
#
# Aquí están las respuestas de cada competidor:
#
# #Respuesta del competitor 1
#
# El impacto social de las tendencias culturales globales en la identidad y la pertenencia de un miembro de una minoría étnica en una sociedad diversa es un tema complejo y multifacético que requiere una comprensión profunda de los cuestiones éticas, sociales y políticas involucradas.
#
# **Los efectos positivos:**
#
# Las tendencias culturales globales pueden tener un impacto positivo en la identidad y la pertenencia de los miembros de las minorías étnicas en varias maneras:
#
# 1. **Representación y reconocimiento:** Las tendencias culturales globales pueden contribuir a la representación y el reconocimiento de las experiencias y perspectivas de las minorías étnicas en los medios, instituciones educativas y espacios públicos. Esto proporciona una imagen más precisa y diversificada del mundo global.
# 2. **Influencia cultural:** Los miembros de las minorías étnicas pueden sentirse identificados y conectados con la cultura global que se refleja en su propia herencia, lo que puede mejorar su sentido de pertenencia a la comunidad global.
# 3. **Oportunidades laborales y educativas:** Las tendencias culturales globales pueden proporcionar oportunidades laborales, educativas y de networking que se centran en la diversidad cultural, lo que puede ser beneficioso para los miembros de las minorías étnicas.
#
# **Los efectos negativos:**
#
# Sin embargo, también existen posibles efectos negativos de las tendencias culturales globales en la identidad y la pertenencia de los miembros de las minorías étnicas:
#
# 1. **Simplificaciones y estereotipos:** Las discusiones dominantes sobre las tendencias culturales globales pueden simplificar o reducir a las experiencias y perspectivas complejas de las minorías étnicas, perpetuando los estereotipos y prejuicios.
# 2. **Culturización:** La adopción de la cultura global puede llevar a la culturaización, es decir, la pérdida de características culturales únicas que definen a una comunidad específica. Esto puede afectar negativamente su identidad y pertenencia.
# 3. **Exclusión y marginación:** La influencia dominanté de las tendencias culturales globales puede conducir a la exclusión y la marginación de ciertos grupos culturales, perpetuando desigualdades y injusticias socias.
#
# **Ejemplos históricos:**
#
# A continuación, se presentan algunos ejemplos históricos que ilustran el impacto social de las tendencias culturales globales en la identidad y la pertenencia de los miembros de las minorías étnicas:
#
# 1. **La inmigración a los Estados Unidos:** La inmigración a los EE.UU. durante la década de 1980, predominantemente de origen latinoamericano, contribuyó al crecimiento cultural de la música latina y el aumento de una identidad globalizada latin@.
# 2. **La creciente influencia del Bollywood en el mundo occidental:** La popularización del cine bollywoodi en países como Reino Unido e India ha permitido que los miembros de las minorías étnicas se sientan más conectados con sus raíces culturales.
#
# **Críticas constructivas:**
#
# Para abordar efectivamente el impacto social de las tendencias culturales globales, es necesario:
#
# 1. **Desafiar simplificaciones y estereotipos:** Abordar las simplificaciones y los estereotipos utilizados en las discusiones dominantes sobre las tendencias culturales globales.
# 2. **Fomentar la inclusión cultural:** Incentivar a las comunidades culturales complejas hacia un diálogo inclusivo, donde todas las experiencias de diversidad son valoradas y representadas.
# 3. **Promover una comprensión ética del mundo global:** Educación crítica es fundamental para comprender los efectos culturales globales en la identidad y la inclusión de individuos minoritarios con perspectiva inter disciplinaria, contextual y éticamente comprometidos.
#
# Al considerar estos ejemplos e implícitos históricos, como well as constructivos críticas hacia simplificaciones y estereotipos utilizados en discusiones dominantes sobre las tendencias globales cultura, podemos trabajar más efectivamente para abordar la complequidad de los impactos sociales que tienen estas tendencias culturales globales en el mundo diverso.
#
# #Respuesta del competitor 2
#
#  La interacción entre las tendencias culturales globales y la identidad y pertenencia de miembros de minorías étnicas en una sociedad diversa puede ser complicada y multifacética. Estas interacciones pueden abarcar efectos positivos, negativos, o complejos dependiendo de la cultura dominante, el contexto histórico y social, y los esfuerzos de inclusión o exclusión en la sociedad.
#
# Uno de los ejemplos más prominentes es la difusión global del hip-hop en la década de 1980 y sus efectos sobre las personas de color en América del Norte, especialmente los afroamericanos y chicanos. El hip-hop actuó como una herramienta para preservar y promover su cultura local, en el contexto de la disminución de la influencia de movimientos culturales colectivos previos y el surgimiento de nuevos desafíos socioeconómicos. Sin embargo, también se utilizó la comercialización del hip-hop por la cultura dominante para sencillez, estereotipo y objetivación de las personas de color, especialmente en los medios.
#
# Por otro lado, la globalización ha proporcionado nuevas oportunidades para promover la diversidad cultural a través de plataformas de comunicación mundial como Internet. Estas plataformas han ayudado a las minorías étnicas a compartir su cultura y tradiciones entre sí y con los no-dominantes, lo que ha contribuido a la construcción de sus identidades más fuertes e informadas. Sin embargo, también pueden presentar desafíos cuando se combina con el nacionalismo o las discusiones políticas que pueden hacer uso del racismo, xenofobia y otras ideologías discriminatorias para propagar estereotipos degradantes sobre personas pertenecientes a comunidades a otras partes de la sociedad.
#
# En conclusion, las tendencias culturales globales tienen un impacto complejo en el contexto social e identidad de miembros de minorías étnicas. Es necesario abordar con precaución los estereotipos y simplicaciones utilizados en discursos dominantes, al tiempo que se reconoce la importancia de las oportunidades que ofrecen estas tendencias para fortalecer e informar la identidad de las minorías étnicas y promover la diversidad cultural.
#
# #Respuesta del competitor 3
#
# Las tendencias culturales globales han impactado significativлова el tejido social, particularmente para miembros de minorías étnicas dentro de sociedades diversas. Estos efectos pueden ser tanto positivos como negativos y puede resultar en una compleja interacción entre identidad cultural y propósito nacional o comunitario compartido que subyace a los conceptos contemporáneos de pertenencia e identidad.
#
# Un ejemplo reciente es la proliferación del "cosmopolitismo" donde las ideas culturales se mezclan fácilmente debido al énfasis en prácticas globales y marcas comerciales; esta globalización a veces perjudica los sentimientos de identidad, ya que puede hacer sutil e irreversible el declive tradicional. Por ejemplo, minoridades como afroamericanos se pueden experimentar una tensión entre la creciente influencia asiática en ciertas industrias culturalmente dominantes (cine/télviso), dejando a miembros de estas comunidades reevaluando su papel únicamente dentro del grupo racial tradicional y también unirse al amplio continuum global, incluso pendientes potenciales deslegitimaciones o menosprecios.
#
# Además la cultura pop frecuentemente promueve estereotipos de minorías étnicas en una manera casual - considera trabajadores asiáticos como extraños precisamente conductores inteligentes, que pueden contribuir a percibir estas culturas no solo fuera del alcance local sino también dentro. Esto puede ser problemático ya que fomentará un estigma basado único y exotismo cultural en lugar de entender la complejidad holística e individualidades propias presente entre todos los miembros de estos grupos étnicos particulares, negando sus propio historias únicas y contextos.
#
# Sin embargo, es importante reconocer las posibles simplificaciones que esto representa una visión limitada porque ofrece un panorama demasiado crudo - muchos individuos en cualquier minoría encuentran suerte mezclando sus costumbres propias con elementos presentes dentro de la cultura general —un fenómeno cultural reciente conocido como 'amalgamación', tal vez visible a través del baile hip hop fusionada comúnmente practicado por miembros afrocaucásicos, donde danza (arte) se percibe uniendo tradiciones culturales.
#
# En otro marco potencial de construcción crítica es destacar los intentos que llevan hacia el multilingue y múltiple culturalidad – la creciente popularización del bilingüismo, particularmente entre las generaciones más jóvenes dentro muchas minorías étnicas podría resultarte en una potencial soberbia nacional pero también un reconocimiento de identidad cruzada. Examinando el movimiento hip hop: comienza como expresión artística originaria afrodescendiente, ahora se fusiona cada vez más con elementos latinos y otros – reflejando estas interacciones dinámicas entre culturas; sin embargo al mismo tiempo las identidades específicas del origen dentro el movimiento pueden comenzar perdidas o marginadas.
#
# En conclusión: los efectos sociales de la cultura globalizadora puede ser bastante cambiantes para minorías – ya sea deslegitimando sus contribuciones únicas al tejido sociocultural en una tierra extranjera, ofreciendo nuevas formas que pueden fusionar tradiciones culturales (como dentro hip hop), la creciente multilingüismo y cultura biculturalidad. Es imperativo desestimar estereotipos simplistas mientras reconocen las complejidades inherentes e historias únicas presentes en individuos de cualquier minoría étnica, así se pueda contribuir una manera más humilde a la diversidad inclusiva alentando conversaciones dinámicas que mejoran el entendimiento y respeto.
#
# Nota: Esta respuesta está elaborada para dar un marco sólido pero conciso de consideración social en torno a los impactos culturales globales sobre minorías étnicas dentro sociedades diversas, utilizando ejemplos específicos recientes y ofreciendo críticas constructivas al poten回 la propaginación simplificaciones o estereotipos presentes. Sin embargo para una exploración más profunda considerar historias personales bajo estas perspectivas podría proporcionar valiosa compr
#
#
#
# Ahora responde con el JSON con el orden clasificado de los competidores, nada más. No incluyas formato markdown ni bloques de código.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
model_name = "qwen/qwen3-32b"

response = groq.chat.completions.create(
    model= modelo,
    messages=judge_messages,
)
results = response.choices[0].message.content
results = re.sub(r'<think>.*?</think>', '', results, flags=re.DOTALL).strip()
print(results)
# Out:
# {"resultados": [3, 2, 1]}

# %%
# OK veamos los resultados

results_dict = json.loads(results)
ranks = results_dict["resultados"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: phi3.5
# Rank 2: mistral:7b
# Rank 3: llama3.2:3b

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Ejercicio</h2>
#             <span style="color:#ff7800;">¿Qué patrón(es) usamos en este experimento? Intenta actualizar esto para añadir otro patrón de diseño Agéntico.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Implicaciones comerciales</h2>
#             <span style="color:#00bfff;">Este tipo de patrones - enviar una tarea a múltiples modelos y evaluar los resultados,
#             son comunes cuando necesitas mejorar la calidad de la respuesta de tu LLM. Este enfoque se puede aplicar de manera
#             universal a proyectos comerciales donde la precisión es crítica.
#             </span>
#         </td>
#     </tr>
# </table>
